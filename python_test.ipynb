# %%
import os
import pandas as pd
import re

path = 'C:/Users/nnair101/Documents/Python/Weather Data/'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.csv' in file:
            f = os.path.join(r, file)
            exec(file.split('.', 1)[0] + "=" + "pd.read_csv(f)")
            print(file.split('.', 1)[0])
            files.append(file)
            
            #print(file)
            #replaced = re.sub('.csv', '', file)
            #print(replaced)
#             listt = list(file)
#             for c in listt:
# Out:
# W_Barrow201697Z
# W_Cantwell201697Z
# W_Dutch_Har_1201697Z
# W_Fairbanks201697Z
# W_Fort_Yuko_1201697Z
# W_Haines201697Z
# W_Bearce201697Z
# W_Bentonville_1201697Z
# W_Blytheville_1201697Z
# W_De_Queen201697Z
# W_El_Dorado_1201697Z
# W_Fayettevill_1201697Z
# W_Anaheim201697Z
# W_Arcata201697Z
# W_Bakersfield_1201697Z
# W_Bishop201697Z
# W_Blythe201697Z
# W_Burbank201697Z
# W_Alma201697Z
# W_Athens201697Z
# W_Atlanta201697Z
# W_Augusta201697Z
# W_Brunswick201697Z
# W_Bloomington201697Z
# W_Columbus201697Z
# W_Elkhart201697Z
# W_Evansville201697Z
# W_Fort_Wayne201697Z
# W_Coffeyville201697Z
#   File "<string>", line 1
#     W_Col Jabara201697Z=pd.read_csv(f)
#                       ^
# SyntaxError: invalid syntax

# %%
W_Barrow201697Z.head(5)
# Out:
#         AKDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2015-10-1                32                 27                21
# 1  2015-10-2                31                 24                17
# 2  2015-10-3                32                 29                25
# 3  2015-10-4                31                 25                19
# 4  2015-10-5                28                 27                26
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              29              25             21            96
# 1              29              24             15           100
# 2              29              27             24           100
# 3              24              22             18            92
# 4              27              25             23            93
#
#     Mean Humidity   Min Humidity          ...            Max VisibilityMiles  \
# 0              84             69          ...                             10
# ...

# %%
files
# Out:
# ['W_Barrow201697Z.csv',
#  'W_Cantwell201697Z.csv',
#  'W_Dutch_Har_1201697Z.csv',
#  'W_Fairbanks201697Z.csv',
#  'W_Fort_Yuko_1201697Z.csv',
#  'W_Haines201697Z.csv',
#  'W_Bearce201697Z.csv',
#  'W_Bentonville_1201697Z.csv',
#  'W_Blytheville_1201697Z.csv',
#  'W_De_Queen201697Z.csv',
#  'W_El_Dorado_1201697Z.csv',
#  'W_Fayettevill_1201697Z.csv',
#  'W_Anaheim201697Z.csv',
#  'W_Arcata201697Z.csv',
#  'W_Bakersfield_1201697Z.csv',
#  'W_Bishop201697Z.csv',
#  'W_Blythe201697Z.csv',
#  'W_Burbank201697Z.csv',
#  'W_Alma201697Z.csv',
#  'W_Athens201697Z.csv',
#  'W_Atlanta201697Z.csv',
#  'W_Augusta201697Z.csv',
#  'W_Brunswick201697Z.csv',
#  'W_Bloomington201697Z.csv',
#  'W_Columbus201697Z.csv',
#  'W_Elkhart201697Z.csv',
#  'W_Evansville201697Z.csv',
#  'W_Fort_Wayne201697Z.csv',
#  'W_Coffeyville201697Z.csv']

# %%
# Concatenate dfs corresponding to same subdirectories. California
import os
import pandas as pd
import re

path = 'C:/Users/nnair101/Documents/Python/Weather Data/CALIFORNIA'

abc = pd.read_csv('C:/Users/nnair101/Documents/Python/Weather Data/CALIFORNIA/F_Anaheim_2/W_Anaheim201697Z.csv')
coll = abc.columns
data_california = pd.DataFrame(columns = coll)

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.csv' in file:
            f = pd.read_csv(os.path.join(r, file))
            data_california = data_california.append(f, ignore_index=True)  
            
data_california.head(5)
# Out:
#          PDT Max TemperatureF Mean TemperatureF Min TemperatureF  \
# 0  2015-10-1               85                77               68
# 1  2015-10-2               83                75               66
# 2  2015-10-3               83                74               64
# 3  2015-10-4               73                67               61
# 4  2015-10-5               76                69               62
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            67.0            62.0           55.0          81.0
# 1            63.0            61.0           54.0          87.0
# 2            65.0            60.0           54.0          84.0
# 3            64.0            58.0           50.0          87.0
# 4            60.0            57.0           54.0          84.0
#
#     Mean Humidity   Min Humidity          ...            Max VisibilityMiles  \
# 0            62.0           43.0          ...                             10
# ...

# %%
#iv. Extract Name of all subdirectories and save as list: States
import os
States = os.listdir('C:/Users/nnair101/Documents/Python/Weather Data/')
States
# Out:
# ['ALASKA',
#  'ARKANSAS',
#  'CALIFORNIA',
#  'GEORGIA',
#  'INDIANA',
#  'KANSAS',
#  'MAINE',
#  'MASSACHUSETTS',
#  'MINNESOTA',
#  'MISSOURI',
#  'NEVADA',
#  'NEW_YORK',
#  'NORTH_DAKOTA',
#  'OKLAHOMA',
#  'SOUTH_CAROLINA',
#  'TENNESSEE',
#  'UTAH',
#  'WASHINGTON',
#  'WISCONSIN',
#  'WYOMING']

# %%
# Q2. dict_abbr
dict_abbr = {}
a = []
for i in States:
    b = i[:3]
    a.append(b)
dict(zip(States, a))
# Out:
# {'ALASKA': 'ALA',
#  'ARKANSAS': 'ARK',
#  'CALIFORNIA': 'CAL',
#  'GEORGIA': 'GEO',
#  'INDIANA': 'IND',
#  'KANSAS': 'KAN',
#  'MAINE': 'MAI',
#  'MASSACHUSETTS': 'MAS',
#  'MINNESOTA': 'MIN',
#  'MISSOURI': 'MIS',
#  'NEVADA': 'NEV',
#  'NEW_YORK': 'NEW',
#  'NORTH_DAKOTA': 'NOR',
#  'OKLAHOMA': 'OKL',
#  'SOUTH_CAROLINA': 'SOU',
#  'TENNESSEE': 'TEN',
#  'UTAH': 'UTA',
#  'WASHINGTON': 'WAS',
#  'WISCONSIN': 'WIS',
#  'WYOMING': 'WYO'}

# %%
# Q3 Create two separate dataframes for State California based on continous/categorical segregation.

#Separating numerical & str features
df_cat = data_california.select_dtypes(exclude=['float64'])
df_con = data_california._get_numeric_data()

# %%
df_cat.dtypes
# Out:
# PDT                      object
# Max TemperatureF         object
# Mean TemperatureF        object
# Min TemperatureF         object
#  Max VisibilityMiles     object
#  Mean VisibilityMiles    object
#  Min VisibilityMiles     object
#  Max Wind SpeedMPH       object
#  Mean Wind SpeedMPH      object
# PrecipitationIn          object
#  CloudCover              object
#  Events                  object
#  WindDirDegrees<br />    object
# dtype: object

# %%
df_cat.head(5)
# Out:
#          PDT Max TemperatureF Mean TemperatureF Min TemperatureF  \
# 0  2015-10-1               85                77               68
# 1  2015-10-2               83                75               66
# 2  2015-10-3               83                74               64
# 3  2015-10-4               73                67               61
# 4  2015-10-5               76                69               62
#
#    Max VisibilityMiles  Mean VisibilityMiles  Min VisibilityMiles  \
# 0                   10                    10                   10
# 1                   10                    10                   10
# 2                   10                    10                   10
# 3                   10                     9                    2
# 4                   10                    10                    9
#
#    Max Wind SpeedMPH  Mean Wind SpeedMPH PrecipitationIn  CloudCover  Events  \
# 0                 12                   5            0.00           0     NaN
# ...

# %%
# Q4. plot Histogram for all the categorical variables simultaneously on the above obtained categorical dataframe
hist = df_cat.hist(bins=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-dcdda4e50e32> in <module>()
#       1 # Q4. plot Histogram for all the categorical variables simultaneously on the above obtained categorical dataframe
# ----> 2 hist = df_cat.hist(bins=3)
#
# C:\Users\nnair101\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2123     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2124                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2125                           layout=layout)
#    2126     _axes = _flatten(axes)
#    2127
#
# ...

# %%
# Q6. count of missing values, mean, std, max, min and  25, 50, 75 percentile values for all continuous fields

# mising values
df_con.isnull().sum()
# Out:
# Max Dew PointF                  4
# MeanDew PointF                  4
# Min DewpointF                   4
# Max Humidity                    4
#  Mean Humidity                  4
#  Min Humidity                   4
#  Max Sea Level PressureIn       2
#  Mean Sea Level PressureIn      2
#  Min Sea Level PressureIn       2
#  Max Gust SpeedMPH            355
# dtype: int64

# %%
# Q5 Consider the following string (4) --
# 	"Catastrophic"
# 	print all possible 3 letter words from the given string

import itertools
Catastrophic = 'Catastrophic'
alphabets = [i for i in Catastrophic]
keywords = itertools.product(alphabets, repeat = 3)
list(keywords)
# Out:
# [('C', 'C', 'C'),
#  ('C', 'C', 'a'),
#  ('C', 'C', 't'),
#  ('C', 'C', 'a'),
#  ('C', 'C', 's'),
#  ('C', 'C', 't'),
#  ('C', 'C', 'r'),
#  ('C', 'C', 'o'),
#  ('C', 'C', 'p'),
#  ('C', 'C', 'h'),
#  ('C', 'C', 'i'),
#  ('C', 'C', 'c'),
#  ('C', 'a', 'C'),
#  ('C', 'a', 'a'),
#  ('C', 'a', 't'),
#  ('C', 'a', 'a'),
#  ('C', 'a', 's'),
#  ('C', 'a', 't'),
#  ('C', 'a', 'r'),
#  ('C', 'a', 'o'),
#  ('C', 'a', 'p'),
#  ('C', 'a', 'h'),
#  ('C', 'a', 'i'),
#  ('C', 'a', 'c'),
#  ('C', 't', 'C'),
#  ('C', 't', 'a'),
#  ('C', 't', 't'),
#  ('C', 't', 'a'),
#  ('C', 't', 's'),
#  ('C', 't', 't'),
#  ('C', 't', 'r'),
#  ('C', 't', 'o'),
#  ('C', 't', 'p'),
#  ('C', 't', 'h'),
#  ('C', 't', 'i'),
#  ('C', 't', 'c'),
#  ('C', 'a', 'C'),
#  ('C', 'a', 'a'),
#  ('C', 'a', 't'),
#  ('C', 'a', 'a'),
#  ('C', 'a', 's'),
#  ('C', 'a', 't'),
#  ('C', 'a', 'r'),
#  ('C', 'a', 'o'),
#  ('C', 'a', 'p'),
#  ('C', 'a', 'h'),
#  ('C', 'a', 'i'),
#  ('C', 'a', 'c'),
#  ('C', 's', 'C'),
#  ('C', 's', 'a'),
# ...

# %%
from pathlib import Path

p = Path('C:/Users/nnair101/Documents/Python/Weather Data/')
subdirectories = [x for x in p.iterdir() if x.is_dir()]

print(subdirectories)
# Out:
# [WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/ALASKA'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/ARKANSAS'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/CALIFORNIA'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/GEORGIA'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/INDIANA'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/KANSAS'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/MAINE'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/MASSACHUSETTS'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/MINNESOTA'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/MISSOURI'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/NEVADA'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/NEW_YORK'), WindowsPath('C:/Users/nnair101/Documents/Python/Weather Data/NORTH_DAKOTA'), WindowsPath('C:/Users/nnair101/Documents/Python
# ...

# %%
#Q7. Palindrome
n=int(input("Enter number:"))
temp=n
rev=0
while(n>0):
    dig=n%10
    rev=rev*10+dig
    n=n//10
if(temp==rev):
    print("The number is a palindrome!")
else:
    print("The number isn't a palindrome!")
# Out:
# Enter number:-1221
# The number isn't a palindrome!

# %%
from itertools import permutations 
  
perm = permutations([5, 6, 7]) 
  
# Print the obtained permutations 
for i in list(perm): 
    print(i)
# Out:
# (5, 6, 7)
# (5, 7, 6)
# (6, 5, 7)
# (6, 7, 5)
# (7, 5, 6)
# (7, 6, 5)

# %%
# Question 9

str = input("Enter a string\n")
modified_string = str[0::2]
print(modified_string)
# Out:
# Enter a string
# 1234
# 13

# %%
#Q10. Intersection of lists
def intersection(lst1, lst2): 
  
    # Use of hybrid method 
    temp = set(lst2) 
    lst3 = [value for value in lst1 if value in temp] 
    return lst3 

lst1 = [1,3,6,78,35,55] 
lst2 = [12,24,35,24,88,120,155]

print(intersection(lst1, lst2))
# Out:
# [35]

# %%
#Q11.
li= [2,5,7,9,11,17,222]
#li.sort()
str = int(input("Enter a int value\n"))
print(li.index(str))
# Out:
# Enter a int value
# 5
# 1
